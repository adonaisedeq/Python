# %%
from tkinter import *
import os
        

 
def register():
    global register_screen
    register_screen = Toplevel(main_screen)
    register_screen.title("Register")
    register_screen.geometry("500x350")
 
    global username
    global password
    global username_entry
    global password_entry
    username = StringVar()
    password = StringVar()
 
    Label(register_screen, text="Please enter the details below", bg="white").pack()
    Label(register_screen, text="").pack()
    username_lable = Label(register_screen, text="Username * ")
    username_lable.pack()
    username_entry = Entry(register_screen, textvariable=username)
    username_entry.pack()
    password_lable = Label(register_screen, text="Password * ")
    password_lable.pack()
    password_entry = Entry(register_screen, textvariable=password)
    password_entry.pack()
    Label(register_screen, text="").pack()
    Button(register_screen, text="Register", width=10, height=1, bg="white", command = register_user).pack()
    
def apply():
    global apply_screen
    firstname = StringVar()
    lastname = StringVar()
    dateofbirth = StringVar()
    qualification = StringVar()
    percent = StringVar()
    project = StringVar()
    salary = StringVar()
    experience = StringVar()
    strength = StringVar()
    address = StringVar()
    declare = StringVar()
  
    
    
    apply_screen = Toplevel(main_screen)
    apply_screen.title("Apply for Job")
    apply_screen.geometry("1000x1000")
    Label(apply_screen,text = "--Enter the details to apply--",font = ("Elephant",20)).pack()
    firstname_lable = Label(apply_screen, text=" First Name :",font = ("times new roman",15))
    firstname_lable.pack()
    firstname_entry = Entry(apply_screen, textvariable=firstname,bd=5,relief=GROOVE)
    firstname_entry.pack()
    lastname_lable = Label(apply_screen, text="Last name :",font = ("times new roman",15))
    lastname_lable.pack()
    lastname_entry = Entry(apply_screen, textvariable=lastname,bd=5,relief=GROOVE)
    lastname_entry.pack()
    dateofbirth_lable = Label(apply_screen, text="Date of Birth :",font = ("times new roman",15))
    dateofbirth_lable.pack()
    dateofbirth_entry = Entry(apply_screen, textvariable=dateofbirth,bd=5,relief=GROOVE)
    dateofbirth_entry.pack()
    qualification_lable = Label(apply_screen, text="Educational Qualification :",font = ("times new roman",15))
    qualification_lable.pack()
    qualification_entry = Entry(apply_screen, textvariable=qualification,bd=5,relief=GROOVE)
    qualification_entry.pack()
    percent_lable = Label(apply_screen, text="Percentage in last class:",font = ("times new roman",15))
    percent_lable.pack()
    percent_entry = Entry(apply_screen, textvariable=percent,bd=5,relief=GROOVE)
    percent_entry.pack()
    project_lable = Label(apply_screen, text="Projects :",font = ("times new roman",15))
    project_lable.pack()
    project_entry = Entry(apply_screen, textvariable=project,bd=5,relief=GROOVE)
    project_entry.pack()
    salary_lable = Label(apply_screen, text="Salary expected :",font = ("times new roman",15))
    salary_lable.pack()
    salary_entry = Entry(apply_screen, textvariable=salary,bd=5,relief=GROOVE)
    salary_entry.pack()
    experience_lable = Label(apply_screen, text="Experience :",font = ("times new roman",15))
    experience_lable.pack()
    experience_entry = Entry(apply_screen, textvariable=experience,bd=5,relief=GROOVE)
    experience_entry.pack()
    strength_lable = Label(apply_screen, text="Strenghts :",font = ("times new roman",15))
    strength_lable.pack()
    strength_entry = Entry(apply_screen, textvariable=strength,bd=5,relief=GROOVE)
    strength_entry.pack()
    address_lable = Label(apply_screen, text="Permanent adress:",font = ("times new roman",15))
    address_lable.pack()
    address_entry = Entry(apply_screen, textvariable=address,bd=5,relief=GROOVE)
    address_entry.pack()
    declare_lable = Label(apply_screen, text="Declaration:",font = ("times new roman",15))
    declare_lable.pack()
    declare_entry = Entry(apply_screen, textvariable=declare,bd=5,relief=GROOVE)
    declare_entry.pack()
    
    Button(apply_screen,text = "Submit",font = ("Elephant",15),width = 10,height = 1,command = application_successful).pack()
    
def application_successful():
    global application_success_screen
    application_success_screen = Toplevel(main_screen)
    application_success_screen.title("Successfully Submitted")
    application_success_screen.geometry("800x400")
    Label(application_success_screen,text= "Your application has been Successfully submitted",font = ("Times new roman",20),fg = "Green").pack()
    Button(application_success_screen,text = "OK",font= ("Times new roman",10),command = delete_login_success).pack()
    
      
 
 
 
 
 
 
def login():
    global login_screen
    login_screen = Toplevel(main_screen)
    login_screen.title("Login")
    login_screen.geometry("500x350")
    Label(login_screen, text="Please enter the details below to login").pack()
    Label(login_screen, text="").pack()
 
    global username_verify
    global password_verify
 
    username_verify = StringVar()
    password_verify = StringVar()
 
    global username_login_entry
    global password_login_entry
 
    Label(login_screen, text="Username * ").pack()
    username_login_entry = Entry(login_screen, textvariable=username_verify)
    username_login_entry.pack()
    Label(login_screen, text="").pack()
    Label(login_screen, text="Password * ").pack()
    password_login_entry = Entry(login_screen, textvariable=password_verify, show= '*')
    password_login_entry.pack()
    Label(login_screen, text="").pack()
    Button(login_screen, text="Login", width=10, height=1, command = login_verify).pack()
 
 
def register_user():
 
    username_info = username.get()
    password_info = password.get()
 
    file = open(username_info, "w")
    file.write(username_info + "\n")
    file = open(password_info,"w")
    file.write(password_info + "\n")
    file.close()
 
    username_entry.delete(0, END)
    password_entry.delete(0, END)
 
    Label(register_screen, text="Registration Successful", fg="green", font=("Times new roman", 15)).pack()
    Label(register_screen, text="Go back to login page", fg="black", font=("Times new roman", 10)).pack()
 

 
def login_verify():
    username1 = username_verify.get()
    password1 = password_verify.get()
    username_login_entry.delete(0, END)
    password_login_entry.delete(0, END)
 
    list_of_files = os.listdir()
    if username1 in list_of_files:
        file1 = open(username1, "r")
        verify = file1.read().splitlines()
        if password1 in verify:
            login_sucess()
 
        else:
            password_not_recognised()
 
    else:
        user_not_found()

 
def login_sucess():
    global login_success_screen
    login_success_screen = Toplevel(login_screen)
    login_success_screen.title("Success to login")
    login_success_screen.geometry("1000x1000")
    Label(login_success_screen, text="Login Success.").pack()
    Label(login_success_screen, text="-----WELCOME TO ONLINE JOB APPLICATION PORTAL-----",font = ("Arial Black",20)).pack()
    Label(login_success_screen,text="  1. Company = Oil India Limited",font = ("Arial rounded Mt Bold",20)).pack()
    Label(login_success_screen,width = 100,text=" * Post name :  Superintending Engineer, Manager, MO, Sr Officer",font =("Times new roman",15)).pack()
    Label(login_success_screen, width = 100, text=" * No. of Posts : 54",font = ("Times new roman",15)).pack()
    Label(login_success_screen, width = 100, text=" * Qualification : Diploma, Degree, PG (Relevnat Discipline)",font = ("Times new roman",15)).pack()
    Label(login_success_screen, width = 100, text=" * Last date to apply : 30-10-2020",font = ("Times new roman",15)).pack()
    Button(login_success_screen,text ="Apply",width = 10,height = 2,command = apply,font = ("Elephant",10),fg = "black").pack()
    
    Label(login_success_screen, width = 100, text=" 2. Company = Cement corporation of India",font = ("Arial rounded Mt Bold",20)).pack()
    Label(login_success_screen, width = 100, text=" * Post name :  Artisan Trainee ",font = ("Times new roman",15)).pack()
    Label(login_success_screen, width = 100, text=" * No of Posts: 20",font = ("Times new roman",15)).pack()
    Label(login_success_screen, width = 100, text=" * Qualification :  10th Class, ITI, B.Sc",font = ("Times new roman",15)).pack()
    Label(login_success_screen, width = 100, text=" * Last date to Apply : 10-11-2020",font = ("Times new roman",15)).pack()
    Button(login_success_screen,text ="Apply",width = 10,height = 2,command = apply,font = ("Elephant",10),fg = "black").pack()
 
    Label(login_success_screen, width = 100, text=" 3. Company =  Northern Coalfields Ltd",font = ("Arial rounded Mt Bold",20)).pack()
    Label(login_success_screen, width = 100, text="  *Post name : Apprentice",font = ("Times new roman",15)).pack()
    Label(login_success_screen, width = 100, text=" * No of Posts :  480 ",font = ("Times new roman",15)).pack()
    Label(login_success_screen, width = 100, text=" *Qualification : 10th, 12th Class ",font = ("Times new roman",15)).pack()
    Label(login_success_screen, width = 100, text=" * Last date to Apply : 15-11-2020",font = ("Times new roman",15)).pack()
    Button(login_success_screen,text ="Apply",width = 10,height = 2,command = apply,font = ("Elephant",10),fg = "black").pack()
 
    Label(login_success_screen, width = 100, text= "4 .Company : NHPC Limited. ", font = ("Arial rounded Mt Bold",20)).pack()
    Label(login_success_screen, width = 100, text=" * Post name : Trade Apprentice ",font = ("Times new Roman",15)).pack()
    Label(login_success_screen, width = 100, text=" * No of Posts : 8",font = ("Times new Roman",15)).pack()
    Label(login_success_screen, width = 100, text=" *Qualification : 10th Class, ITI (Relevant Trades)",font = ("Times new Roman",15)).pack()
    Label(login_success_screen, width = 100, text=" * Last date to apply :15-11-2020",font = ("Times new Roman",15)).pack()
    Button(login_success_screen,text ="Apply",width = 10,height = 2,command = apply,font = ("Elephant",10),fg = "black").pack()
 
    Label(login_success_screen, width = 100, text=" 5. Company : THDC India Limited ",font = ("Arial rounded Mt Bold",20)).pack()
    Label(login_success_screen, width = 100, text="* Post name : ITI Trade Apprentice",font = ("Times new roman",15)).pack()
    Label(login_success_screen, width = 100, text=" * No of Posts: 10 ",font = ("Times new roman",15)).pack()
    Label(login_success_screen, width = 100, text=" * Qualification : 10th Class & ITI",font = ("Times new roman",15)).pack()
    Label(login_success_screen, width = 100, text=" Last date to apply : 28-11-2020 ",font = ("Times new roman",15)).pack()
    Button(login_success_screen,text ="Apply",width = 10,height = 2,command = apply,font = ("Elephant",10),fg = "black").pack()
 
    
 


    
    
    
    
    
def password_not_recognised():
    global password_not_recog_screen
    password_not_recog_screen = Toplevel(login_screen)
    password_not_recog_screen.title("Success")
    password_not_recog_screen.geometry("500x300")
    Label(password_not_recog_screen, text="Invalid Password ").pack()
    Button(password_not_recog_screen, text="OK", command=delete_password_not_recognised).pack()
 
 
def user_not_found():
    global user_not_found_screen
    user_not_found_screen = Toplevel(login_screen)
    user_not_found_screen.title("Failed : Wrong Credentials")
    user_not_found_screen.geometry("500x400")
    Label(user_not_found_screen, text="Invlid Username").pack()
    Button(user_not_found_screen, text="OK", command=delete_user_not_found_screen).pack()
 
def delete_login_success():
    login_success_screen.destroy()
    application_success_screen.destroy()
    apply_screen.destroy()
    login_screen.destroy()
    main_screen.destroy()
 
def delete_password_not_recognised():
    password_not_recog_screen.destroy()
 
 
def delete_user_not_found_screen():
    user_not_found_screen.destroy()
 
 
 
def main_account_screen():
    global main_screen
    main_screen = Tk()
    main_screen.geometry("500x250")
    main_screen.title("Credentials Needed for Job Application portal")
    Label(text="Select Your Choice", bg="White", width="100", height="2", font=("Times new Roman", 18)).pack()
    Label(text="").pack()
    Button(text="Login", height="2", width="30", command = login).pack()
    Label(text="").pack()
    Button(text="Register",height="2", width="30", command = register).pack()
    
    main_screen.mainloop()
 
 
main_account_screen()
